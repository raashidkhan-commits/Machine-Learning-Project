# %% [markdown]
# Let us check which model performs the best:
# 1. Linear Regression Model
# 2. Decision Tree Regression Model
# 3. Random Forest Model

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
data=pd.read_csv('/Users/raashidkhan/desktop/GitHub-Projects/Machine-Learning-Project/data/split/stratified_train_set.csv')
data.columns
# Out:
# Index(['clean__longitude', 'clean__latitude', 'clean__housing_median_age',
#        'clean__total_rooms', 'clean__total_bedrooms', 'clean__population',
#        'clean__households', 'clean__median_income',
#        'clean__median_house_value', 'cleaned__ocean_proximity_<1H OCEAN',
#        'cleaned__ocean_proximity_INLAND', 'cleaned__ocean_proximity_ISLAND',
#        'cleaned__ocean_proximity_NEAR BAY',
#        'cleaned__ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
features=data.drop(columns='clean__median_house_value').columns
X=data[features]
y=data['clean__median_house_value']

# %%
models={
    'Linear Regression Model':LinearRegression(),
    'Decision Tree Regression Model':DecisionTreeRegressor(),
    'Random Forest Model':RandomForestRegressor()
}

# %%
for name,model in models.items():
    neg_mse_scores=cross_val_score(model, X,y, cv=10,scoring='neg_mean_squared_error')
    rmse_scores=np.sqrt(-neg_mse_scores)
    model.fit(X, y)
    train_rmse = root_mean_squared_error(y, model.predict(X))
    print (f"{name}: Mean RMSE CV={rmse_scores.mean()}, Standard Deviation={rmse_scores.std()}, RMSE Training Error={train_rmse}")
# Out:
# Linear Regression Model: Mean RMSE CV=69204.28031938952, Standard Deviation=2371.950950228208, RMSE Training Error=69050.51211595758
# Decision Tree Regression Model: Mean RMSE CV=68865.6120024028, Standard Deviation=2573.619664747464, RMSE Training Error=0.0
# Random Forest Model: Mean RMSE CV=49485.66137142114, Standard Deviation=1945.8835750455064, RMSE Training Error=18357.278604710635

# %% [markdown]
# Here, the winner is RandomForestRegressor.
# It has:
# 1. Lowest cross-validation RMSE
# 2. Some gap between train and CV means slight overfitting
# 3. Far better generalization than Decision Tree, and more flexible than Linear Regression.
